# %%
import pandas as pd
import zipfile
from openpyxl import Workbook

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# Read data from the 'sub' and 'num' tabs for fraud
fraud_sub_data = pd.read_csv("gdrive/My Drive/Colab Notebooks/SEC_Data/fraud_sub.csv")
fraud_num_data = pd.read_csv("gdrive/My Drive/Colab Notebooks/SEC_Data/fraud_num.csv")

# %%
# Read data from the 'sub' and 'num' tabs
sub_data = pd.read_csv("gdrive/My Drive/Colab Notebooks/SEC_Data/sub.csv")
num_data = pd.read_csv("gdrive/My Drive/Colab Notebooks/SEC_Data/num.csv")

# %%
# concat non-fraud and fraud data
sub_data = pd.concat([sub_data, fraud_sub_data])
num_data = pd.concat([num_data, fraud_num_data])

# %%
# Create a new DataFrame by grouping and summing values for duplicate combinations of 'adsh' and 'tag'
new_df = num_data.groupby(['adsh', 'tag'], as_index=False)['value'].sum()
new_df.head()
# Out:
#                    adsh                                                tag  \
# 0  0000002178-22-000089                             AccountsPayableCurrent
# 1  0000002178-22-000089               AccountsPayableRelatedPartiesCurrent
# 2  0000002178-22-000089                       AccountsReceivableNetCurrent
# 3  0000002178-22-000089            AccountsReceivableRelatedPartiesCurrent
# 4  0000002178-22-000089  AccruedAutomobileAndWorkersCompensationClaimsC...
#
#          value
# 0  385347000.0
# 1      20000.0
# 2  336579000.0
# 3       7000.0
# 4    8301000.0

# %%
# Merge 'sub' and 'num' dataframes based on the 'adsh' column
merged_data = pd.merge(sub_data, new_df[['adsh', 'tag', 'value']], on='adsh', how='left')

# Pivot the 'tag' column into separate columns with 'value' as the values
#pivoted_data = merged_data.pivot(index='adsh', columns='tag', values='value').reset_index()

# Write the resulting data to a new Excel file
#output_file = "output_file.xlsx"
#pivoted_data.to_excel(output_file, index=False, engine='openpyxl')

#print(f"Output file '{output_file}' created successfully.")
#

# %%
merged_data.shape
# Out:
# (1164400, 39)

# %%
merged_data.head()
# Out:
#    Unnamed: 0                  adsh    cik         name     sic countryba  \
# 0           0  0000014707-22-000072  14707  CALERES INC  3140.0        US
# 1           0  0000014707-22-000072  14707  CALERES INC  3140.0        US
# 2           0  0000014707-22-000072  14707  CALERES INC  3140.0        US
# 3           0  0000014707-22-000072  14707  CALERES INC  3140.0        US
# 4           0  0000014707-22-000072  14707  CALERES INC  3140.0        US
#
#   stprba    cityba  zipba               bas1  ...  fp     filed  \
# 0     MO  ST LOUIS  63105  8300 MARYLAND AVE  ...  Q3  20221206
# 1     MO  ST LOUIS  63105  8300 MARYLAND AVE  ...  Q3  20221206
# 2     MO  ST LOUIS  63105  8300 MARYLAND AVE  ...  Q3  20221206
# 3     MO  ST LOUIS  63105  8300 MARYLAND AVE  ...  Q3  20221206
# 4     MO  ST LOUIS  63105  8300 MARYLAND AVE  ...  Q3  20221206
#
#                 accepted prevrpt detail                  instance nciks aciks  \
# 0  2022-12-06 14:50:00.0       0      1  cal-20221029x10q_htm.xml     1   NaN
# 1  2022-12-06 14:50:00.0       0      1  cal-20221029x10q_htm.xml     1   NaN
# 2  2022-12-06 14:50:00.0       0      1  cal-20221029x10q_htm.xml     1   NaN
# 3  2022-12-06 14:50:00.0       0      1  cal-20221029x10q_htm.xml     1   NaN
# 4  2022-12-06 14:50:00.0       0      1  cal-20221029x10q_htm.xml     1   NaN
#
#                                                  tag        value
# 0                        AccountsPayableTradeCurrent  963258000.0
# 1  AccountsReceivableAllowanceForCreditLossWriteO...    3024000.0
# 2                       AccountsReceivableNetCurrent  445495000.0
# 3                          AccruedIncomeTaxesCurrent   76099000.0
# 4                       AccruedIncomeTaxesNoncurrent   12714000.0
#
# [5 rows x 39 columns]

# %%
nan_count = merged_data["value"].isna().sum()
nan_count
# Out:
# 16558

# %%
merged_data_new = merged_data.dropna(subset=['value'])
merged_data_new.shape
# Out:
# (1147842, 39)

# %%
merged_data_new = merged_data_new[["adsh", "name", "period", "filed", "tag", "value"]]
merged_data_new.head()
# Out:
#                    adsh         name      period     filed  \
# 0  0000014707-22-000072  CALERES INC  20221031.0  20221206
# 1  0000014707-22-000072  CALERES INC  20221031.0  20221206
# 2  0000014707-22-000072  CALERES INC  20221031.0  20221206
# 3  0000014707-22-000072  CALERES INC  20221031.0  20221206
# 4  0000014707-22-000072  CALERES INC  20221031.0  20221206
#
#                                                  tag        value
# 0                        AccountsPayableTradeCurrent  963258000.0
# 1  AccountsReceivableAllowanceForCreditLossWriteO...    3024000.0
# 2                       AccountsReceivableNetCurrent  445495000.0
# 3                          AccruedIncomeTaxesCurrent   76099000.0
# 4                       AccruedIncomeTaxesNoncurrent   12714000.0

# %%
pivoted_data = merged_data_new.pivot(index='adsh', columns='tag', values='value').reset_index()
pivoted_data.head()
# Out:
# tag                  adsh  A155SeniorNotesDue2026  A2.30seniornotesdue2024  \
# 0    0000002178-22-000089                     NaN                      NaN
# 1    0000002488-22-000170                     NaN                      NaN
# 2    0000002969-22-000054                     NaN                      NaN
# 3    0000003499-22-000027                     NaN                      NaN
# 4    0000003570-22-000106                     NaN                      NaN
#
# tag  A2.95seniornotesdue2029  A2020LaborDayWildfireEarningsTestReserve  \
# 0                        NaN                                       NaN
# 1                        NaN                                       NaN
# 2                        NaN                                       NaN
# 3                        NaN                                       NaN
# 4                        NaN                                       NaN
#
# tag  A2020SpecialAdvanceOfferingMaximumBalance  A2021NoteFaceAmount  \
# 0                                          NaN                  NaN
# 1                                          NaN                  NaN
# 2                                          NaN                  NaN
# 3                                          NaN                  NaN
# 4                                          NaN                  NaN
#
# tag  A2021NoteInterestRateStatedPercentage  A2021SeniorNotes  \
# 0                                      NaN               NaN
# 1                                      NaN               NaN
# 2                                      NaN               NaN
# 3                                      NaN               NaN
# 4                                      NaN               NaN
#
# tag  A2022NoteFaceAmount  ...  warrantLiabilityExpense  warrants  \
# 0                    NaN  ...                      NaN       NaN
# 1                    NaN  ...                      NaN       NaN
# 2                    NaN  ...                      NaN       NaN
# 3                    NaN  ...                      NaN       NaN
# 4                    NaN  ...                      NaN       NaN
#
# tag  warrantsToPurchaseSharesOfCommonStock  weightedAveragePricePercentage  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                      NaN                             NaN
#
# tag  workingCapital  workingCapitalDeficit  workingCapitalLoan  \
# 0               NaN                    NaN                 NaN
# 1               NaN                    NaN                 NaN
# 2               NaN                    NaN                 NaN
# 3               NaN                    NaN                 NaN
# 4               NaN                    NaN                 NaN
#
# tag  workingCapitalLoans  workingCapitalSurplus  workingsCapital
# 0                    NaN                    NaN              NaN
# 1                    NaN                    NaN              NaN
# 2                    NaN                    NaN              NaN
# 3                    NaN                    NaN              NaN
# 4                    NaN                    NaN              NaN
#
# [5 rows x 150851 columns]

# %%
pivoted_data.shape
# Out:
# (7429, 150851)

# %%
nan_count = pivoted_data.isnull().sum()
cols = nan_count[nan_count > 6000]
print(cols)
# Out:
# tag
# A155SeniorNotesDue2026                       7428
# A2.30seniornotesdue2024                      7428
# A2.95seniornotesdue2029                      7428
# A2020LaborDayWildfireEarningsTestReserve     7428
# A2020SpecialAdvanceOfferingMaximumBalance    7428
#                                              ...
# workingCapitalDeficit                        7422
# workingCapitalLoan                           7426
# workingCapitalLoans                          7428
# workingCapitalSurplus                        7428
# workingsCapital                              7428
# Length: 150709, dtype: int64

# %%
cols.index[0]
# Out:
# 'A155SeniorNotesDue2026'

# %%
pivoted_data_new = pivoted_data.drop(columns=cols.index, axis=1)
pivoted_data_new.shape
# Out:
# (7429, 142)

# %%
#pivoted_data_new.to_csv("gdrive/My Drive/Colab Notebooks/SEC_Data/2022q4_secdata.csv")
pivoted_data_new.to_csv("gdrive/My Drive/Colab Notebooks/SEC_Data/2022_secdata_WFL.csv")

# %%
#pivoted_data_new = pivoted_data.dropna(axis=1, thresh=1500)
#pivoted_data_new.shape

# %%
#pivoted_data_new.head()
